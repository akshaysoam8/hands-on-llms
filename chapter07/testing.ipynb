# %%
# !CMAKE_ARGS="-DGGML_METAL=on" pip install llama-cpp-python==0.2.69 --upgrade --force-reinstall --no-cache-dir
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.5/42.5 MB 1.8 MB/s eta 0:00:0000:0100:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 1.9 MB/s eta 0:00:00a 0:00:01
# ...
#   Created wheel for llama-cpp-python: filename=llama_cpp_python-0.2.69-cp312-cp312-macosx_26_0_arm64.whl size=3423098 sha256=d69d5e19df148792348bbe079f3c7d390387a2da2c2a67d4935ad805b8f7218c
#   Stored in directory: /private/var/folders/mm/8f6yv2ws36z44ypyr3trh7kr0000gp/T/pip-ephem-wheel-cache-00cbklup/wheels/34/c4/0f/5e9491cacdb3fbcf00fe83a619f2579f1e9fcd2a556694a56f
# Successfully built llama-cpp-python
# ...
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.15.0
#     Uninstalling typing_extensions-4.15.0:
#       Successfully uninstalled typing_extensions-4.15.0
# ...
